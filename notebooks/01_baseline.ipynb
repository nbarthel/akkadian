# %% [markdown]
# # Deep Past Challenge: Akkadian to English Translation
#
# **Baseline Notebook**
#
# This notebook provides a starting point for the Deep Past Challenge competition.

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

# Set paths
if os.path.exists('/kaggle/input'):
    # Running on Kaggle
    DATA_DIR = Path('/kaggle/input/deep-past-initiative-machine-translation')
    OUTPUT_DIR = Path('/kaggle/working')
else:
    # Running locally
    DATA_DIR = Path('../data/raw')
    OUTPUT_DIR = Path('../submissions')

print(f"Data directory: {DATA_DIR}")
print(f"Output directory: {OUTPUT_DIR}")

# %% [markdown]
# ## Load Data

# %%
# List available files
if DATA_DIR.exists():
    print("Available files:")
    for f in DATA_DIR.iterdir():
        print(f"  - {f.name}")
else:
    print("Data directory not found. Download data first.")

# %%
# Load training data
# train_df = pd.read_csv(DATA_DIR / 'train.csv')
# test_df = pd.read_csv(DATA_DIR / 'test.csv')
# sample_submission = pd.read_csv(DATA_DIR / 'sample_submission.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# TODO: Explore the data structure
# - What columns are available?
# - What does the Akkadian text look like?
# - What are the target translations?

# %% [markdown]
# ## Model
#
# Evaluation metric: **Geometric mean of BLEU and chrF++**
#
# $$\text{Score} = \sqrt{\text{BLEU} \times \text{chrF++}}$$

# %%
# TODO: Implement translation model
# Options to explore:
# - Fine-tuned transformer models (mT5, mBART, NLLB)
# - Sequence-to-sequence with attention
# - LLM-based translation (if allowed)

# %% [markdown]
# ## Generate Predictions

# %%
# TODO: Generate translations for test set
# predictions = model.translate(test_df['akkadian'])

# %% [markdown]
# ## Create Submission

# %%
# submission = pd.DataFrame({
#     'id': test_df['id'],
#     'translation': predictions
# })
# submission.to_csv(OUTPUT_DIR / 'submission.csv', index=False)
# print(f"Submission saved to {OUTPUT_DIR / 'submission.csv'}")
